# %% [markdown]
# # CNN Training
#
# Target of this code is to train a CNN network to extract the needle position of an analog needle device.
#
# ### Preparing the training
# * First all libraries are loaded
#     * It is assumed, that they are installed during the Python setup
# * matplotlib is set to print the output inline in the jupyter notebook

# %%
########### Basic Parameters for Running: ################################
    
TFlite_Version  = "1101"   
TFlite_MainType = "gauge-cont"
TFlite_Size     = "s2"
Training_Percentage = 0.2              # 0.0 = Use all Images for Training
Epoch_Anz = 100

##########################################################################



import os
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import numpy as np
from sklearn.utils import shuffle
from tensorflow.python import keras
from tensorflow.python.keras import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Conv2D, MaxPool2D, Flatten, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import History 
import math
from PIL import Image 

loss_ges = np.array([])
val_loss_ges = np.array([])

# %matplotlib inline
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load training data
# * The data is expected in the "Input_dir"
# * Picture size must be 32x32 with 3 color channels (RGB)
# * The filename contains the informations needed for training in the first 3 digits::
# * Typical filename:
#     * x.y-zzzz.jpg
#     * e.g. "4.6_Lfd-1406_zeiger3_2019-06-02T050011"
#
# |Place holder | Meaning                     | Usage        |
# |------------- |-----------------------------|--------------|
# | **x.y**          | readout value               | **to be learned** |
# | zzzz        | additional information              | not needed   |
#
# * The images are stored in the x_data[]
# * The expected output for each image in the corresponding y_data[]
#     * The periodic nature is reflected in a **sin/cos coding**, which allows to restore the angle/counter value with an arctan later on.
#
# * The last step is a shuffle (from sklearn.utils) as the filenames are on order due to the encoding of the expected analog readout in the filename

# %%
Input_dir='data_resize_all'

files = glob.glob(Input_dir + '/*.*')
x_data = []
y_data = []

for aktfile in files:
    test_image = Image.open(aktfile)
    test_image = np.array(test_image, dtype="float32")
    test_image = np.reshape(test_image, (32,32,3))
    base = os.path.basename(aktfile)
    target_number = (float(base[0:3])) / 10
    target_sin = math.sin(target_number * math.pi * 2)
    target_cos = math.cos(target_number * math.pi * 2)

    x_data.append(test_image)
    zw = np.array([target_sin, target_cos])
    y_data.append(zw)

x_data = np.array(x_data)
y_data = np.array(y_data)
print(x_data.shape)
print(y_data.shape)

x_data, y_data = shuffle(x_data, y_data)

if (Training_Percentage > 0):
    X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)
else:
    X_train = x_data
    y_train = y_data
# Out:
# (100, 32, 32, 3)
# (100, 2)

# %% [markdown]
# ### Define the model
#
# The layout of the network ist a typcial CNN network with alternating **Conv2D** and **MaxPool2D** layers. Finished after **flattening** with additional **Dense** layer.
#
# #### Important
# * Shape of the input layer: (32, 32, 3)
# * Shape of the output layer: (2) - sin and cos

# %%
inputs = tf.keras.Input(shape=(32, 32, 3))
inputs2 = tf.keras.layers.BatchNormalization()(inputs)
inputs3 = tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation="relu")(inputs2)
inputs4 = tf.keras.layers.MaxPool2D(pool_size=(4,4))(inputs3)
inputs5 = tf.keras.layers.Conv2D(16, (5, 5), padding='same', activation="relu")(inputs4)
inputs6 = tf.keras.layers.MaxPool2D(pool_size=(2,2))(inputs5)
inputs7 = tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation="relu")(inputs6)
inputs8 = tf.keras.layers.MaxPool2D(pool_size=(2,2))(inputs7)
inputs9 = tf.keras.layers.Flatten()(inputs8)
inputs10 = tf.keras.layers.Dense(128,activation="relu")(inputs9)
inputs11 = tf.keras.layers.Dense(64,activation="relu")(inputs10)
output = tf.keras.layers.Dense(2)(inputs11)

model = tf.keras.Model(inputs=inputs, outputs=output)

model.compile(loss=keras.losses.mean_squared_error, optimizer=tf.keras.optimizers.Adadelta(learning_rate=1.0, rho=0.95), metrics = ["accuracy"])

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  batch_normalization_2 (Batc  (None, 32, 32, 3)        12
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        2432
#
#  max_pooling2d_6 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 16)          12816
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_8 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 44,798
# Trainable params: 44,792
# Non-trainable params: 6
# _________________________________________________________________

# %% [markdown]
# # Training
# The input pictures are randomly scattered for brightness and pixel shift variations. These is implemented with a ImageDataGenerator.
#
#
# The training is splitted into two steps:
# 1. Variation of the brightness only
# 2. Variation of brightness and Pixel Shift

# %% [markdown]
# ### Step 1: Brigthness scattering only

# %%
Batch_Size = 8
Epoch_Anz = 30
Shift_Range = 0
Brightness_Range = 0.3

datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], height_shift_range=[-Shift_Range,Shift_Range],brightness_range=[1-Brightness_Range,1+Brightness_Range])

if (Training_Percentage > 0):
    train_iterator = datagen.flow(x_data, y_data, batch_size=Batch_Size)
    validation_iterator = datagen.flow(X_test, y_test, batch_size=Batch_Size)
    history = model.fit_generator(train_iterator, validation_data = validation_iterator, epochs = Epoch_Anz)
else:
    train_iterator = datagen.flow(x_data, y_data, batch_size=Batch_Size)
    history = model.fit_generator(train_iterator, epochs = Epoch_Anz)
# Out:
# Epoch 1/30
# C:\Users\nos86\AppData\Local\Temp\ipykernel_1141948\3831122756.py:11: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_iterator, validation_data = validation_iterator, epochs = Epoch_Anz)
# 13/13 [==============================] - 1s 32ms/step - loss: 0.5074 - accuracy: 0.6000 - val_loss: 3.7643 - val_accuracy: 0.4000
# Epoch 2/30
# 13/13 [==============================] - 0s 16ms/step - loss: 0.3795 - accuracy: 0.6300 - val_loss: 0.8516 - val_accuracy: 0.4000
# Epoch 3/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1815 - accuracy: 0.8700 - val_loss: 0.4588 - val_accuracy: 0.4500
# Epoch 4/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.1008 - accuracy: 0.9800 - val_loss: 0.2028 - val_accuracy: 0.9000
# Epoch 5/30
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0425 - accuracy: 0.9100 - val_loss: 0.0716 - val_accuracy: 0.9000
# Epoch 6/30
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.8500
# Epoch 7/30
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0232 - accuracy: 0.9800 - val_loss: 0.0538 - val_accuracy: 0.8500
# Epoch 8/30
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0144 - accuracy: 0.9800 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 9/30
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0100 - accuracy: 0.9700 - val_loss: 0.0313 - val_accuracy: 0.9000
# Epoch 10/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0074 - accuracy: 0.9900 - val_loss: 0.0268 - val_accuracy: 0.8500
# Epoch 11/30
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0267 - accuracy: 0.9600 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 12/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0200 - accuracy: 0.9700 - val_loss: 0.0316 - val_accuracy: 1.0000
# Epoch 13/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0180 - accuracy: 0.9500 - val_loss: 0.0226 - val_accuracy: 0.8000
# Epoch 14/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0247 - accuracy: 0.9800 - val_loss: 0.0050 - val_accuracy: 0.9500
# Epoch 15/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0121 - accuracy: 0.9500 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 16/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0105 - accuracy: 0.9800 - val_loss: 0.0345 - val_accuracy: 0.8500
# Epoch 17/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0131 - accuracy: 0.9700 - val_loss: 0.0105 - val_accuracy: 0.9500
# Epoch 18/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0262 - accuracy: 0.9600 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 19/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0055 - accuracy: 0.9400 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 20/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0155 - accuracy: 0.9800 - val_loss: 0.0186 - val_accuracy: 0.8500
# Epoch 21/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0318 - accuracy: 0.9900 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 22/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0133 - accuracy: 0.9500 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 23/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0041 - accuracy: 0.9800 - val_loss: 0.0045 - val_accuracy: 0.9000
# Epoch 24/30
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0171 - accuracy: 0.9700 - val_loss: 0.0031 - val_accuracy: 0.9500
# Epoch 25/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0063 - accuracy: 0.9800 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 26/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0115 - accuracy: 0.9800 - val_loss: 0.0140 - val_accuracy: 0.9500
# Epoch 27/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0135 - accuracy: 0.9900 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 28/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0126 - accuracy: 0.9700 - val_loss: 0.0120 - val_accuracy: 0.9500
# Epoch 29/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 30/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0119 - accuracy: 0.9600 - val_loss: 0.0209 - val_accuracy: 0.8000

# %% [markdown]
# ### Step 1: Learing result
#
# * Visualization of the training and validation results

# %%
loss_ges = np.append(loss_ges, history.history['loss'])

if (Training_Percentage > 0):
    val_loss_ges = np.append(val_loss_ges, history.history['val_loss'])
    plt.semilogy(val_loss_ges)

plt.semilogy(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','eval'], loc='upper left')
plt.show()

# %% [markdown]
# ### Step 2: Brigthness and Pixel Shift scattering
# Here a higher number of epochs is used to reach the minimum loss function

# %%
Batch_Size = 8
Epoch_Anz = 160
Shift_Range = 3
Brightness_Range = 0.3

datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], height_shift_range=[-Shift_Range,Shift_Range],brightness_range=[1-Brightness_Range,1+Brightness_Range])

if (Training_Percentage > 0):
    train_iterator = datagen.flow(x_data, y_data, batch_size=Batch_Size)
    validation_iterator = datagen.flow(X_test, y_test, batch_size=Batch_Size)
    history = model.fit_generator(train_iterator, validation_data = validation_iterator, epochs = Epoch_Anz)
else:
    train_iterator = datagen.flow(x_data, y_data, batch_size=Batch_Size)
    history = model.fit_generator(train_iterator, epochs = Epoch_Anz)
# Out:
# Epoch 1/160
#  6/13 [============>.................] - ETA: 0s - loss: 0.4776 - accuracy: 0.6250
# C:\Users\nos86\AppData\Local\Temp\ipykernel_1141948\1492021130.py:11: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_iterator, validation_data = validation_iterator, epochs = Epoch_Anz)
# 13/13 [==============================] - 0s 23ms/step - loss: 0.4014 - accuracy: 0.6900 - val_loss: 0.2756 - val_accuracy: 0.9000
# Epoch 2/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.1760 - accuracy: 0.8100 - val_loss: 0.0505 - val_accuracy: 0.8000
# Epoch 3/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0794 - accuracy: 0.8600 - val_loss: 0.0404 - val_accuracy: 0.9500
# Epoch 4/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0377 - accuracy: 0.9500 - val_loss: 0.0126 - val_accuracy: 0.9000
# Epoch 5/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0189 - accuracy: 0.9800 - val_loss: 0.0133 - val_accuracy: 0.9500
# Epoch 6/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0146 - accuracy: 0.9600 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 7/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0196 - accuracy: 0.9700 - val_loss: 0.0284 - val_accuracy: 1.0000
# Epoch 8/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0157 - accuracy: 0.9300 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 9/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0147 - accuracy: 0.9600 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 10/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.8500
# Epoch 11/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0198 - accuracy: 0.9700 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 12/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0171 - accuracy: 0.9700 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 13/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0232 - accuracy: 0.9900 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 14/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0141 - accuracy: 0.9600 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 15/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0161 - accuracy: 0.9800 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 16/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0102 - accuracy: 0.9900 - val_loss: 0.0350 - val_accuracy: 0.9500
# Epoch 17/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0197 - accuracy: 0.9600 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 18/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0158 - accuracy: 0.9500 - val_loss: 0.0357 - val_accuracy: 0.8000
# Epoch 19/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0161 - accuracy: 0.9600 - val_loss: 0.0123 - val_accuracy: 0.9500
# Epoch 20/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0170 - accuracy: 0.9900 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 21/160
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0197 - accuracy: 0.9600 - val_loss: 0.0131 - val_accuracy: 0.9000
# Epoch 22/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0130 - accuracy: 0.9900 - val_loss: 0.0271 - val_accuracy: 0.8500
# Epoch 23/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0152 - accuracy: 0.9900 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 24/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0110 - accuracy: 0.9600 - val_loss: 0.0065 - val_accuracy: 0.9500
# Epoch 25/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0174 - accuracy: 0.9800 - val_loss: 0.0194 - val_accuracy: 0.9500
# Epoch 26/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0160 - accuracy: 0.9600 - val_loss: 0.0129 - val_accuracy: 0.9000
# Epoch 27/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0139 - accuracy: 0.9700 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 28/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0105 - accuracy: 0.9700 - val_loss: 0.0081 - val_accuracy: 0.9000
# Epoch 29/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0132 - accuracy: 0.9700 - val_loss: 0.0154 - val_accuracy: 0.8500
# Epoch 30/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0142 - accuracy: 0.9200 - val_loss: 0.0048 - val_accuracy: 0.9500
# Epoch 31/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0177 - accuracy: 0.9600 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 32/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.8500
# Epoch 33/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0123 - accuracy: 0.9800 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 34/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0098 - accuracy: 0.9700 - val_loss: 0.0070 - val_accuracy: 0.9000
# Epoch 35/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9500
# Epoch 36/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0091 - accuracy: 0.9600 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 37/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0113 - accuracy: 0.9700 - val_loss: 0.0036 - val_accuracy: 0.9000
# Epoch 38/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0107 - accuracy: 0.9800 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 39/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0148 - accuracy: 0.9600 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 40/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0078 - accuracy: 0.9900 - val_loss: 0.0063 - val_accuracy: 0.9500
# Epoch 41/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 42/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0097 - accuracy: 0.9700 - val_loss: 0.0096 - val_accuracy: 0.9000
# Epoch 43/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0144 - accuracy: 0.9700 - val_loss: 0.0275 - val_accuracy: 0.9500
# Epoch 44/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0136 - accuracy: 0.9600 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 45/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0153 - accuracy: 0.9900 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 46/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0067 - accuracy: 0.9800 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 47/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0108 - accuracy: 0.9800 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 48/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0083 - accuracy: 0.9600 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 49/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0127 - accuracy: 0.9800 - val_loss: 0.0140 - val_accuracy: 0.9000
# Epoch 50/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9500
# Epoch 51/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0056 - accuracy: 0.9900 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 52/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0075 - accuracy: 0.9900 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 53/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 54/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0104 - accuracy: 0.9500 - val_loss: 0.0059 - val_accuracy: 0.9500
# Epoch 55/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0147 - accuracy: 0.9800 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 56/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0198 - accuracy: 0.9600 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 57/160
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0094 - accuracy: 0.9800 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 58/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 59/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0103 - accuracy: 0.9800 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 60/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0088 - accuracy: 0.9800 - val_loss: 0.0047 - val_accuracy: 0.9500
# Epoch 61/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0073 - accuracy: 0.9500 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 62/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0069 - accuracy: 0.9700 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 63/160
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0134 - accuracy: 0.9600 - val_loss: 0.0319 - val_accuracy: 0.9500
# Epoch 64/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0125 - accuracy: 0.9600 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 65/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0059 - accuracy: 0.9900 - val_loss: 0.0146 - val_accuracy: 0.8500
# Epoch 66/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0081 - accuracy: 0.9900 - val_loss: 0.0081 - val_accuracy: 0.9500
# Epoch 67/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0091 - accuracy: 0.9800 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 68/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0074 - accuracy: 0.9700 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 69/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0105 - accuracy: 0.9700 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 70/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 71/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 0.9800 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 72/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0097 - accuracy: 0.9700 - val_loss: 0.0087 - val_accuracy: 0.9500
# Epoch 73/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0056 - accuracy: 0.9900 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 74/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0058 - accuracy: 0.9900 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 75/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0083 - accuracy: 0.9900 - val_loss: 0.0038 - val_accuracy: 0.9000
# Epoch 76/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0056 - accuracy: 0.9500 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 77/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0117 - accuracy: 0.9800 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 78/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.8500
# Epoch 79/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0117 - accuracy: 0.9900 - val_loss: 0.0168 - val_accuracy: 0.8500
# Epoch 80/160
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0071 - accuracy: 0.9800 - val_loss: 0.0034 - val_accuracy: 0.9500
# Epoch 81/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0045 - accuracy: 0.9600 - val_loss: 0.0054 - val_accuracy: 0.9500
# Epoch 82/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0060 - accuracy: 0.9800 - val_loss: 0.0068 - val_accuracy: 0.9500
# Epoch 83/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0070 - accuracy: 0.9700 - val_loss: 0.0046 - val_accuracy: 0.9000
# Epoch 84/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0052 - accuracy: 0.9800 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 85/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0051 - accuracy: 0.9800 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 86/160
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0090 - accuracy: 0.9800 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 87/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0112 - accuracy: 0.9800 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 88/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0060 - accuracy: 0.9700 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 89/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0086 - accuracy: 0.9900 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 90/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0051 - accuracy: 0.9800 - val_loss: 0.0180 - val_accuracy: 0.9500
# Epoch 91/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0061 - accuracy: 0.9800 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 92/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0079 - accuracy: 0.9800 - val_loss: 0.0147 - val_accuracy: 0.9500
# Epoch 93/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0106 - accuracy: 0.9600 - val_loss: 0.0070 - val_accuracy: 0.9000
# Epoch 94/160
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0078 - accuracy: 0.9900 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 95/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0056 - accuracy: 0.9900 - val_loss: 0.0063 - val_accuracy: 0.9500
# Epoch 96/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0038 - accuracy: 0.9700 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 97/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9500
# Epoch 98/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0072 - accuracy: 0.9800 - val_loss: 0.0036 - val_accuracy: 0.9500
# Epoch 99/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 100/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0075 - accuracy: 0.9900 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 101/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0059 - accuracy: 0.9900 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 102/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0058 - accuracy: 0.9700 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 103/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0052 - accuracy: 0.9900 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 104/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9500
# Epoch 105/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 106/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0079 - accuracy: 0.9700 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 107/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0068 - accuracy: 0.9700 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 108/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0065 - accuracy: 0.9900 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 109/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0033 - accuracy: 0.9900 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 110/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0090 - accuracy: 0.9600 - val_loss: 0.0181 - val_accuracy: 0.9000
# Epoch 111/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0037 - accuracy: 0.9900 - val_loss: 0.0039 - val_accuracy: 0.9500
# Epoch 112/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0081 - accuracy: 0.9800 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 113/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0065 - accuracy: 0.9600 - val_loss: 0.0040 - val_accuracy: 0.9500
# Epoch 114/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0067 - accuracy: 0.9900 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 115/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 116/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0051 - accuracy: 0.9800 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 117/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 118/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0064 - accuracy: 0.9900 - val_loss: 0.0050 - val_accuracy: 0.9000
# Epoch 119/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0059 - accuracy: 0.9700 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 120/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0042 - accuracy: 0.9800 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 121/160
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 122/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0062 - accuracy: 0.9700 - val_loss: 0.0027 - val_accuracy: 0.9500
# Epoch 123/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 0.9800 - val_loss: 0.0195 - val_accuracy: 0.8500
# Epoch 124/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 0.9500
# Epoch 125/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 126/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 0.9700 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 127/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0036 - accuracy: 0.9900 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 128/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0069 - accuracy: 0.9900 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 129/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0045 - accuracy: 0.9800 - val_loss: 0.0026 - val_accuracy: 0.9500
# Epoch 130/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 0.9800 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 131/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0073 - accuracy: 0.9900 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 132/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0047 - accuracy: 0.9900 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 133/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0041 - accuracy: 0.9900 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 134/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0049 - accuracy: 0.9800 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 135/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 136/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0053 - accuracy: 0.9700 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 137/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0039 - accuracy: 0.9700 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 138/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0057 - accuracy: 0.9900 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 139/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 0.9700 - val_loss: 0.0066 - val_accuracy: 0.9500
# Epoch 140/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0043 - accuracy: 0.9900 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 141/160
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0056 - accuracy: 0.9800 - val_loss: 0.0043 - val_accuracy: 0.9000
# Epoch 142/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 0.9900 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 143/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0039 - accuracy: 0.9800 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 144/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0063 - accuracy: 0.9800 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 145/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0030 - accuracy: 0.9700 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 146/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0027 - accuracy: 0.9800 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 147/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0042 - accuracy: 0.9800 - val_loss: 0.0029 - val_accuracy: 0.9500
# Epoch 148/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0058 - accuracy: 0.9900 - val_loss: 0.0059 - val_accuracy: 0.9000
# Epoch 149/160
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0087 - accuracy: 0.9800 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 150/160
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0033 - accuracy: 0.9900 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 151/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0040 - accuracy: 0.9900 - val_loss: 0.0023 - val_accuracy: 0.9500
# Epoch 152/160
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0038 - accuracy: 0.9900 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 153/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9500
# Epoch 154/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 155/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 0.9700 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 156/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 0.9800 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 157/160
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0056 - accuracy: 0.9900 - val_loss: 0.0034 - val_accuracy: 0.9500
# Epoch 158/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0052 - accuracy: 0.9900 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 159/160
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0075 - accuracy: 0.9900 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 160/160
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0069 - accuracy: 0.9600 - val_loss: 0.0065 - val_accuracy: 0.9000

# %% [markdown]
# ### Overall Learing results (Step 1 & Step 2)

# %%
loss_ges = np.append(loss_ges, history.history['loss'])


if (Training_Percentage > 0):
    val_loss_ges = np.append(val_loss_ges, history.history['val_loss'])
    plt.semilogy(val_loss_ges)


plt.semilogy(loss_ges)
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','eval'], loc='upper left')
plt.show()

# %% [markdown]
# ### Check the model by hand
#
# * The following code uses the trained model to check the deviation for each picture.
# * The evaluation takes the periodic character of the results into account (dev1 ... dev2).
# * Images, that have a bigger deviation as the parameter "deviation_max_list" are printed in a list to check the picture and labeling itself

# %%
Input_dir='data_resize_all'
#Input_dir='test_result'
files = glob.glob(Input_dir + '/*.*')
res = []
stat_Anz = []
stat_Abweichung = []
i = 0
deviation_max_list = 0.05

for i in range(100):
    stat_Anz.append(0)
    stat_Abweichung.append(0)

for aktfile in sorted(files):
    base = os.path.basename(aktfile)
    target = (float(base[0:3])) / 10
    
    target_sin = math.sin(target * math.pi * 2)
    target_cos = math.cos(target * math.pi * 2)

    test_image = Image.open(aktfile)
    test_image = np.array(test_image, dtype="float32")
    img = np.reshape(test_image,[1,32,32,3])
    classes = model.predict(img, verbose=0)
    
    out_sin = classes[0][0]  
    out_cos = classes[0][1]
    out_target = (np.arctan2(out_sin, out_cos)/(2*math.pi)) % 1

    dev_sin = target_sin - out_sin
    dev_cos = target_cos - out_cos
    dev_target = target - out_target
    
    if abs(dev_target + 1) < abs(dev_target):
        out_target = out_target - 1
        dev_target = target - out_target
    else:
        if abs(dev_target - 1) < abs(dev_target):
            out_target = out_target + 1
            dev_target = target - out_target
            
    target_int = int ((float(base[0:3])) * 10)
    stat_Abweichung[target_int] = stat_Abweichung[target_int] + dev_target  
    stat_Anz[target_int] = stat_Anz[target_int] + 1
               
    res.append(np.array([target, out_target, dev_target, out_sin, out_cos, i]))
    if abs(dev_target) > deviation_max_list:
        print(aktfile + " " + str(target) + " " + str(out_target) +  " " + str(dev_target))

    
for i in range(100):
    stat_Abweichung[i] = stat_Abweichung[i] / stat_Anz[i]

res = np.asarray(res)
res_step_1 = res
# Out:
# data_resize_all\1.2_gas_tank.jpg 0.12 0.17902836506492756 -0.05902836506492756
# data_resize_all\1.4_gas_tank.jpg 0.13999999999999999 0.19095543112108077 -0.05095543112108078
# data_resize_all\2.0_gas_tank.jpg 0.2 0.2557019247670012 -0.0557019247670012
# data_resize_all\2.1_gas_tank.jpg 0.21000000000000002 0.26249817169138856 -0.05249817169138854
# data_resize_all\2.2_gas_tank.jpg 0.22000000000000003 0.2774753915306448 -0.05747539153064479
# data_resize_all\2.3_gas_tank.jpg 0.22999999999999998 0.281891298556535 -0.051891298556535015
# data_resize_all\4.1_gas_tank.jpg 0.41 0.46601200602090403 -0.05601200602090406
# data_resize_all\5.4_gas_tank.jpg 0.54 0.5972113364673559 -0.05721133646735588
# data_resize_all\5.5_gas_tank.jpg 0.55 0.6044966818545592 -0.05449668185455914
# data_resize_all\9.8_gas_tank.jpg 0.9800000000000001 0.9272204165211152 0.052779583478884895
# data_resize_all\9.9_gas_tank.jpg 0.99 0.9297762211334778 0.06022377886652219

# %% [markdown]
# ## Results

# %%
plt.plot(res[:,3])
plt.plot(res[:,4])
plt.title('Result')
plt.ylabel('value')
plt.xlabel('#Picture')
plt.legend(['sin', 'cos'], loc='lower left')
plt.show()

# %%
plt.plot(res[:,0])
plt.plot(res[:,1])
plt.title('Result')
plt.ylabel('Counter Value')
plt.xlabel('#Picture')
plt.legend(['Orginal', 'Prediction'], loc='upper left')
plt.show()

# %%
plt.plot(stat_Abweichung)
plt.title('Result')
plt.ylabel('Counter Value')
plt.xlabel('#Picture')
plt.legend(['Orginal', 'Prediction'], loc='upper left')
plt.show()

# %%
plt.plot(stat_Anz)
plt.title('Result')
plt.ylabel('Counter Value')
plt.xlabel('#Picture')
plt.legend(['Orginal', 'Prediction'], loc='upper left')
plt.show()

# %% [markdown]
# ### Deviation from Expected Value

# %%
plt.plot(res[:,2])
plt.title('Deviation')
plt.ylabel('Deviation from expected value')
plt.xlabel('#Picture')
plt.legend(['Deviation'], loc='upper left')
#plt.ylim(-0.3, 0.3)
plt.show()

statistic = np.array([np.mean(res[:,2]), np.std(res[:,2]), np.min(res[:,2]), np.max(res[:,2])])
print(statistic)
# Out:
# [-0.017   0.0275 -0.059   0.0602]

# %% [markdown]
# ### Save the model
#
# * Save the model to the file with the "h5" file format

# %%
FileName = TFlite_MainType + "_" + TFlite_Version + "_" + TFlite_Size

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open(FileName + ".tflite", "wb").write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\nos86\AppData\Local\Temp\tmp9wdo2vr0\assets
# INFO:tensorflow:Assets written to: C:\Users\nos86\AppData\Local\Temp\tmp9wdo2vr0\assets
# 183980

# %%
from pathlib import Path
import tensorflow as tf

FileName = FileName = TFlite_MainType + "_" + TFlite_Version + "_" + TFlite_Size + "_q.tflite"

def representative_dataset():
    for n in range(x_data[0].size):
      data = np.expand_dims(x_data[5], axis=0)
      yield [data.astype(np.float32)]
        
converter2 = tf.lite.TFLiteConverter.from_keras_model(model)
converter2.representative_dataset = representative_dataset
converter2.optimizations = [tf.lite.Optimize.DEFAULT]
converter2.representative_dataset = representative_dataset
tflite_quant_model = converter2.convert()

open(FileName, "wb").write(tflite_quant_model)
print(FileName)
Path(FileName).stat().st_size
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpc4seh5wj/assets
# INFO:tensorflow:Assets written to: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpc4seh5wj/assets
# /opt/homebrew/Caskroom/miniforge/base/envs/mlp2/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# 2022-09-13 23:06:16.837898: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2022-09-13 23:06:16.837913: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2022-09-13 23:06:16.837998: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpc4seh5wj
# 2022-09-13 23:06:16.839380: I tensorflow/cc/saved_model/reader.cc:81] Reading meta graph with tags { serve }
# 2022-09-13 23:06:16.839386: I tensorflow/cc/saved_model/reader.cc:122] Reading SavedModel debug info (if present) from: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpc4seh5wj
# 2022-09-13 23:06:16.844637: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2022-09-13 23:06:16.897968: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /var/folders/07/sj9pw71n205_354358yc8scm0000gn/T/tmpc4seh5wj
# 2022-09-13 23:06:16.916300: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 78302 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: 0, output_inference_type: 0
# ana-cont_1101_s2_q.tflite
# 53328
